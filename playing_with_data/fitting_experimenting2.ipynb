# %% [markdown]
# A continuation of `fitting_experimenting1.ipynb` (it was getting a little long and hard to find stuff)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import landau

# %%
x = np.linspace(-4,14,1000)
plt.title(r"Landau Probability Density Function for $\mu=0,~c=1$")
plt.plot(x,landau.pdf(x,0,1))
plt.grid(True)
plt.show()

x = np.linspace(-4,14,1000)
plt.title(r"Landau Probability Density Function for $\mu=0,~c=1$")
plt.plot(x,np.log(landau.pdf(x,0,1)))
plt.grid(True)
plt.show()
